# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Data

# %%
df_raw = pd.read_csv("creditcard.csv")
df_raw.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df_raw.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %% [markdown]
# # Transformation

# %%
# transforming amount values in the scale of other columns

from sklearn.preprocessing import StandardScaler, RobustScaler

robust_scaler = RobustScaler()

df_raw['Amount'] =robust_scaler.fit_transform(df_raw['Amount'].values.reshape(-1,1))

# %%
sns.color_palette("colorblind")
plt.style.use("seaborn")
plt.figure(figsize=(12,6))
sns.countplot('Class', data=df_raw)
plt.ylabel("Frequency Count")
plt.title("Fraud Vs Non Fradu")
plt.show()
# Out:
# /Users/ilkersenturk/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Data is imbalance, there are ways to make it balance, firt Unser Sampling method will be used

# %% [markdown]
# # Under Sampling

# %%
fraud_df = df_raw[df_raw['Class'] == 1]
total_number_of_fraud = len(fraud_df)

nonfraud_df = df_raw[df_raw['Class'] == 0]
non_fraud_sample_indexes  = np.random.choice(nonfraud_df.index, total_number_of_fraud, replace= False)
non_fraud_sample_indexes = np.array(non_fraud_sample_indexes)

nonfraud_sample_df = df_raw.iloc[non_fraud_sample_indexes]



df = pd.concat([fraud_df, nonfraud_sample_df])

# %%
df.value_counts("Class")
# Out:
# Class
# 0    492
# 1    492
# dtype: int64

# %% [markdown]
# # Feature Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import f_classif,SelectKBest

X = df.drop(columns=['Class','Time'])
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = True, random_state = 42)



selector = SelectKBest(f_classif, k =5)
selector.fit_transform(X_train, y_train)



print(X_train.columns[selector.get_support(indices=True)])
# Out:
# Index(['V4', 'V10', 'V11', 'V12', 'V14'], dtype='object')

# %%
#Correlations

target_correlation = np.abs(df.corr()[['Class']]).sort_values('Class', ascending = False)

plt.style.use("seaborn")
plt.figure(figsize=(18,10))

plt.bar(height = target_correlation['Class'], x = target_correlation.index)
# Out:
# <BarContainer object of 31 artists>

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5)

model.fit(X_train, y_train)

feature_names_rff = []
for name, score in zip(X_train.columns, model.feature_importances_):
  if score > 0.06:
    feature_names_rff.append(name)


print(feature_names_rff)
# Out:
# ['V3', 'V4', 'V10', 'V11', 'V12', 'V14', 'V17']

# %%
from xgboost import XGBClassifier, plot_importance

model = XGBClassifier()
model.fit(X_train,y_train)
plot_importance(model)
# Out:
# [17:10:28] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/ilkersenturk/opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
features = ['V4', 'V10', 'V11', 'V12', 'V14' ]

X = df[features]
y = df['Class']

# %%
plt.figure(figsize=(18,10))
sns.heatmap(X.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(len(features),2, figsize =(14,30))


for index, col_name in enumerate(features):
  sns.boxenplot(x = 'Class',y =str(col_name), data = df, ax = axes[index][0])
  sns.kdeplot(y =str(col_name), data=df,ax=axes[index][1], shade=True)

# %%
def remove_outliner(data, col_name):

  q25, q75 = np.percentile(data[col_name],25),np.percentile(data[col_name],75)

  iqr = q75 - q25
  cut_off = iqr * 1.7
  lower, upper = q25 - cut_off, q75 + cut_off
  outliners = data[(data[col] < lower) | (data[col] > upper)]
  print("there are total {} outliners will be removed".format(len(outliners)))
    
  data = data.drop(outliners.index)

  return data

# %%
for col in features:
  df = remove_outliner(df, col)
# Out:
# there are total 7 outliners will be removed
# there are total 64 outliners will be removed
# there are total 11 outliners will be removed
# there are total 7 outliners will be removed
# there are total 0 outliners will be removed

# %%
X = df[features]
y = df['Class']
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, shuffle =True, random_state = 42, stratify =y)

# %%
import time
from sklearn.manifold import TSNE


t0 = time.time()
X_tsne = TSNE(n_components=2, random_state=42).fit_transform(X.values)
t1 = time.time()
print("T-SNE took {:.2} s".format(t1 - t0))

f, (ax) = plt.subplots(1, 1, figsize=(14,10))

# t-SNE scatter plot

sns.scatterplot(X_tsne[:,0],X_tsne[:,1], hue=y, ax = ax, linewidths =3)

ax.set_title('t-SNE', fontsize=14)

plt.show()
# Out:
# T-SNE took 2.4 s
# /Users/ilkersenturk/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Model Parameter Updates

# %%
# model selecting
import warnings
warnings.filterwarnings('ignore')



from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV


classifiers = {
    "log": LogisticRegression(),
    "knn": KNeighborsClassifier(),
    "svc": SVC(),
    "rff": RandomForestClassifier()
}
params = {
    "log" : {"penalty": ['l1', 'l2'], 'C': [0.001, 0.01, 0.1, 1,5, 10, 100, 1000]},
    "knn" : {"n_neighbors": list(range(2,5,1)), 'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']},
    "svc" :   {'C': [0.5, 0.7, 0.9, 1], 'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
    "rff" : {"criterion": ["gini", "entropy"], "max_depth": list(range(2,4,1)),              "min_samples_leaf": list(range(5,7,1))}
}

best_params = {
    "log" : 0,
    "knn" : 0,
    "svc" : 0,
    "rff" : 0 
}

for key  in classifiers.keys():
    model = GridSearchCV(classifiers[key] , params[key])
    model.fit(X_train,y_train)
    best_params[key] = model.best_params_

# %%
best_params
# Out:
# {'log': {'C': 100, 'penalty': 'l2'},
#  'knn': {'algorithm': 'auto', 'n_neighbors': 4},
#  'svc': {'C': 0.9, 'kernel': 'rbf'},
#  'rff': {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5}}

# %%
from sklearn.model_selection import cross_val_score

classifiers = {
    "log": LogisticRegression(C=0.01, penalty = 'l2'),
    "knn": KNeighborsClassifier(algorithm='auto', n_neighbors = 2),
    "svc": SVC(C=0.5, kernel='sigmoid'),
    "rff": RandomForestClassifier(criterion='entropy', max_depth=3, min_samples_leaf=6)
}


for key in classifiers:
    model = classifiers[key]
    model.fit(X_train,y_train)
    score = cross_val_score(model, X_train, y_train, cv = 10)
    print("Classifiers: ",key, "Has a training score of", round(score.mean(), 2) * 100, "% accuracy score")
# Out:
# Classifiers:  log Has a training score of 93.0 % accuracy score
# Classifiers:  knn Has a training score of 93.0 % accuracy score
# Classifiers:  svc Has a training score of 92.0 % accuracy score
# Classifiers:  rff Has a training score of 92.0 % accuracy score

# %%
from sklearn.metrics import classification_report


for key in classifiers:
    model = classifiers[key]
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print("Classification Report", str(key).upper())
    print(classification_report(y_pred, y_test))
# Out:
# Classification Report LOG
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95       136
#            1       0.86      1.00      0.93        88
#
#     accuracy                           0.94       224
#    macro avg       0.93      0.95      0.94       224
# weighted avg       0.95      0.94      0.94       224
#
# Classification Report KNN
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93       137
#            1       0.84      0.99      0.91        87
#
#     accuracy                           0.92       224
#    macro avg       0.92      0.94      0.92       224
# weighted avg       0.93      0.92      0.92       224
#
# Classification Report SVC
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       124
#            1       0.92      0.94      0.93       100
#
#     accuracy                           0.94       224
# ...

# %% [markdown]
# # HOW THE MODEL PERFORMS ON WHOLE DATASET

# %%
from sklearn.metrics import confusion_matrix

test = df_raw[features]
y_test = df_raw['Class']


from sklearn.metrics import classification_report
fig,ax = plt.subplots(nrows=len(classifiers),ncols=1,figsize=(8, len(classifiers)* 6))
for i,key in  enumerate(classifiers):
    model = classifiers[key]
    model.fit(X_train,y_train)
    y_pred = model.predict(test)

    cf_matrix = confusion_matrix(y_test, y_pred)
    sns.heatmap(cf_matrix, annot=True,ax = ax[i],cbar=False, fmt='g', cmap='Blues')


    ax[i].set_xlabel("Predicted")
    ax[i].set_ylabel("Actual")

# %% [markdown]
# # Over Sampling

# %%
from imblearn.over_sampling import ADASYN 
ada = ADASYN(random_state=42)
X_ada, y_ada = ada.fit_resample(X, y)

# %%
X_ada_train_, X_ada_test, y_ada_train, y_ada_test = train_test_split(X_ada, y_ada, test_size = 0.15, shuffle = True, random_state = 42)

model = LogisticRegression(C=1, penalty = 'l2')

model.fit(X_ada_train_,y_ada_train)
score = cross_val_score(model, X_ada_train_, y_ada_train, cv = 5)
print("Classifiers: ","Logistic", "Has a training score of", round(score.mean(), 2) * 100, "% accuracy score")

score = cross_val_score(model, X_ada_test, y_ada_test, cv = 5)
print("Classifiers: ","Logistic", "Has a test score of", round(score.mean(), 2) * 100, "% accuracy score")
# Out:
# Classifiers:  Logistic Has a training score of 88.0 % accuracy score
# Classifiers:  Logistic Has a test score of 83.0 % accuracy score

# %%
y_pred = model.predict(X_ada_test)

print("Classification Report", str(key).upper())
print(classification_report(y_pred, y_ada_test))
# Out:
# Classification Report RFF
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88        80
#            1       0.82      0.91      0.87        67
#
#     accuracy                           0.87       147
#    macro avg       0.87      0.87      0.87       147
# weighted avg       0.88      0.87      0.87       147

# %%
fig = plt.figure(figsize=(12,6))

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
precision, recall, _ = precision_recall_curve(y_ada_test, y_pred)
average_precision = average_precision_score(y_ada_test,y_pred)
plt.step(recall, precision, color='r', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='#F59B00')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('OverSampling Precision-Recall curve: \n Average Precision-Recall Score ={0:0.2f}'.format(
          average_precision), fontsize=16)
# Out:
# Text(0.5, 1.0, 'OverSampling Precision-Recall curve: \n Average Precision-Recall Score =0.84')

# %%
from imblearn.over_sampling import SMOTE 

sm = SMOTE(random_state=42)
X = df_raw[features]
y = df_raw['Class']
print("before smote there are {} x and {} y and {} y1 class".format(len(X),len(y), 492))

X_sm, y_sm = sm.fit_resample(X,y)

print("After smote there are {} x_sm and {} y_sm and {} fraud class {} non-fraud class".format(len(X_sm),len(y_sm), np.sum(y_sm==1), np.sum(y_sm == 0)))
# Out:
# before smote there are 284807 x and 284807 y and 492 y1 class
# After smote there are 568630 x_sm and 568630 y_sm and 284315 fraud class 284315 non-fraud class

# %%
X_sm_train, X_sm_test, y_sm_train, y_sm_test = train_test_split(X_sm, y_sm, test_size = 0.15, shuffle = True, random_state = 42)

model = LogisticRegression(C=1, penalty = 'l2')

model.fit(X_sm_train,y_sm_train)
score = cross_val_score(model, X_sm_train, y_sm_train, cv = 5)
print("Classifiers: ","logistic", "Has a training score of", round(score.mean(), 2) * 100, "% accuracy score")


score = cross_val_score(model, X_sm_test, y_sm_test, cv = 5)
print("Classifiers: ","Logistic", "Has a training score of", round(score.mean(), 2) * 100, "% accuracy score")
# Out:
# Classifiers:  logistic Has a training score of 94.0 % accuracy score
# Classifiers:  Logistic Has a training score of 94.0 % accuracy score

# %%
y_pred = model.predict(X_sm_test)

print("Classification Report", str(key).upper())
print(classification_report(y_pred, y_sm_test))
# Out:
# Classification Report RFF
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94     45877
#            1       0.90      0.97      0.94     39418
#
#     accuracy                           0.94     85295
#    macro avg       0.94      0.94      0.94     85295
# weighted avg       0.94      0.94      0.94     85295

# %%
fig = plt.figure(figsize=(12,6))

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
precision, recall, _ = precision_recall_curve(y_sm_test, y_pred)
average_precision = average_precision_score(y_sm_test,y_pred)
plt.step(recall, precision, color='r', alpha=0.4,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='#F59B00')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('OverSampling Precision-Recall curve: \n Average Precision-Recall Score ={0:0.2f}'.format(
          average_precision), fontsize=16)
# Out:
# Text(0.5, 1.0, 'OverSampling Precision-Recall curve: \n Average Precision-Recall Score =0.93')

# %%
classifiers = {
    "log": LogisticRegression(C=1, penalty = 'l2'),
    "rff": RandomForestClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5),
    
}


for key in classifiers:
    model = classifiers[key]
    model.fit(X_sm_train,y_sm_train)
    score = cross_val_score(model, X_sm_test, y_sm_test, cv = 3)
    print("Classifiers: ",key, "Has a test score of", round(score.mean(), 2) * 100, "% accuracy score")
# Out:
# Classifiers:  log Has a test score of 94.0 % accuracy score
# Classifiers:  rff Has a test score of 94.0 % accuracy score
